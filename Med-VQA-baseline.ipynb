# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Projects/Med-VQA-baseline # or any other folder path
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Projects/Med-VQA-baseline # or any other folder path'
# /content/drive/MyDrive/Projects/Med-VQA-baseline

# %%
# %ls
# Out:
#  ans2label.json                 inference.py             models/             requirement-linux.txt
#  data/                          label2ans.json           node_modules/       requirement.txt
#  data_pipeline/                 logs.txt                 package.json        streamlit.py
# 'How to use localtunnel.gdoc'   Med-VQA-baseline.ipynb   package-lock.json   synpic676.jpg
#  image.jpg                      model/                   README.md           train.py

# %%
# %%python3 --version
# Out:
# Python 3.11.11

# %%
# %pip install -r requirement-linux.txt

# %%
# !python train.py

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 23 packages in 1s
# ⠇
# ⠇3 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠏

# %%
# !streamlit run streamlit.py &> ./logs.txt &

# %%
# !curl ipv4.icanhazip.com && npx localtunnel --port 8501
# Out:
# 34.16.191.40
# ⠙your url is: https://curvy-papers-type.loca.lt
# ^C

# %%
# !pkill streamlit
